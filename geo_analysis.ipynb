# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
outline_border = gpd.read_file(
    "./geodata/small_bangladesh_geojson_adm0_whole_bangladesh_outline.json"
)
divisions = gpd.read_file(
    "./geodata/small_bangladesh_geojson_adm1_8_divisions_bibhags.json"
)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax = outline_border.plot(ax=ax, edgecolor="red", linewidth=2)
ax.set_title("Border of Bangladesh")
# Out:
# Text(0.5, 1.0, 'Border of Bangladesh')

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax = divisions.plot(ax=ax, edgecolor="red", linewidth=2)
ax.set_title("Division of Bangladesh with area specification")
# Out:
# Text(0.5, 1.0, 'Division of Bangladesh with area specification')

# %%
# Divisions name
division_name = divisions.ADM1_EN
division_name
# Out:
# 0       Barisal
# 1    Chittagong
# 2         Dhaka
# 3        Khulna
# 4    Mymensingh
# 5      Rajshahi
# 6       Rangpur
# 7        Sylhet
# Name: ADM1_EN, dtype: object

# %%
division_infected = [
    1,
    2,
    5 + 17,
    12 + 13 + 1 + 1 + 1,
    9 + 2,
    1 + 10 + 29 + 14 + 3 + 12,
    1 + 12 + 6 + 9 + 24 + 3 + 16,
    1,
]

# %%
divisions["Infected"] = division_infected

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax = divisions.plot(
    ax=ax, edgecolor="black", column="Infected", markersize=10, legend=True
)

divisions.apply(
    lambda x: ax.annotate(
        text=x.ADM1_EN, xy=x.geometry.centroid.coords[0], ha="center"
    ),
    axis=1,
)
ax.set_title("Name of Divisions in Bangladesh")
# Out:
# Text(0.5, 1.0, 'Name of Divisions in Bangladesh')

# %%
divisions
# Out:
#    Shape_Leng  Shape_Area     ADM1_EN ADM1_PCODE ADM1_REF ADM1ALT1EN  \
# 0   25.424604    0.889395     Barisal       BD10     None       None
# 1   30.287321    2.737796  Chittagong       BD20     None       None
# 2   12.197758    1.806506       Dhaka       BD30     None       None
# 3   38.409385    1.826575      Khulna       BD40     None       None
# 4    8.166577    0.941812  Mymensingh       BD45     None       None
# 5    8.410221    1.624856    Rajshahi       BD50     None       None
# 6   15.369683    1.465681     Rangpur       BD55     None       None
# 7    9.800293    1.103963      Sylhet       BD60     None       None
#
#   ADM1ALT2EN     ADM0_EN ADM0_PCODE        date     validOn validTo  \
# 0       None  Bangladesh         BD  2015-01-01  2020-11-13    None
# 1       None  Bangladesh         BD  2015-01-01  2020-11-13    None
# 2       None  Bangladesh         BD  2015-01-01  2020-11-13    None
# 3       None  Bangladesh         BD  2015-01-01  2020-11-13    None
# ...

# %%
districts = [
    "Nawabganj",
    "Panchagarh",
    "Thakurgaon",
    "Nilphamari",
    "Dinajpur",
    "Lalmonirhat",
    "Kurigram",
    "Rangpur",
    "Gaibandha",
    "Joypurhat",
    "Naogaon",
    "Rajshahi",
    "Bogra",
    "Natore",
    "Mymensingh",
    "Tangail",
    "Meherpur",
    "Kushtia",
    "Pabna",
    "Manikganj",
    "Dhaka",
    "Chuadanga",
    "Jhenaidah",
    "Magura",
    "Faridpur",
    "Narsingdi",
    "Comilla",
    "Narail",
    "Gopalganj",
    "Madaripur",
    "Shariatpur",
    "Khulna",
    "Jhalokati",
]

# %%
infected = [
    1,
    1,
    12,
    6,
    9,
    24,
    3,
    16,
    1,
    10,
    29,
    13,
    3,
    9,
    2,
    12,
    13,
    12,
    5,
    17,
    1,
    1,
    2,
    6,
    71,
    1,
    1,
    1,
    8,
    6,
    3,
    1,
    1,
]

# %%
sum(infected)
# Out:
# 301

# %%
d = {k: v for (k, v) in zip(districts, infected)}

# %%
d
# Out:
# {'Nawabganj': 1,
#  'Panchagarh': 1,
#  'Thakurgaon': 12,
#  'Nilphamari': 6,
#  'Dinajpur': 9,
#  'Lalmonirhat': 24,
#  'Kurigram': 3,
#  'Rangpur': 16,
#  'Gaibandha': 1,
#  'Joypurhat': 10,
#  'Naogaon': 29,
#  'Rajshahi': 13,
#  'Bogra': 3,
#  'Natore': 9,
#  'Mymensingh': 2,
#  'Tangail': 12,
#  'Meherpur': 13,
#  'Kushtia': 12,
#  'Pabna': 5,
#  'Manikganj': 17,
#  'Dhaka': 1,
#  'Chuadanga': 1,
#  'Jhenaidah': 2,
#  'Magura': 6,
#  'Faridpur': 71,
#  'Narsingdi': 1,
#  'Comilla': 1,
#  'Narail': 1,
#  'Gopalganj': 8,
#  'Madaripur': 6,
#  'Shariatpur': 3,
#  'Khulna': 1,
#  'Jhalokati': 1}

# %%
districts_zillas = gpd.read_file(
    "./geodata/small_bangladesh_geojson_adm2_64_districts_zillas.json"
)

# %%
districts_zillas
# Out:
#     Shape_Leng  Shape_Area     ADM2_EN ADM2_PCODE ADM2_REF ADM2ALT1EN  \
# 0    12.929816    0.319709    Bagerhat     BD4001     None       None
# 1     5.358126    0.401359   Bandarban     BD2003     None       None
# 2     4.167970    0.117801     Barguna     BD1004     None       None
# 3     7.713625    0.195228     Barisal     BD1006     None       None
# 4    10.091155    0.170812       Bhola     BD1009     None       None
# ..         ...         ...         ...        ...      ...        ...
# 59    3.596003    0.221992   Sirajganj     BD5088     None       None
# 60    4.741768    0.330139   Sunamganj     BD6090     None       None
# 61    4.338167    0.305453      Sylhet     BD6091     None       None
# 62    3.644558    0.299525     Tangail     BD3093     None       None
# 63    3.245973    0.163550  Thakurgaon     BD5594     None       None
#
#    ADM2ALT2EN     ADM1_EN ADM1_PCODE     ADM0_EN ADM0_PCODE        date  \
# ...

# %%
district_names = districts_zillas.ADM2_EN

# %%
district_names
# Out:
# 0       Bagerhat
# 1      Bandarban
# 2        Barguna
# 3        Barisal
# 4          Bhola
#          ...
# 59     Sirajganj
# 60     Sunamganj
# 61        Sylhet
# 62       Tangail
# 63    Thakurgaon
# Name: ADM2_EN, Length: 64, dtype: object

# %%
infected = []
for name in district_names:
    if name in districts:
        infected.append(d[name])
    else:
        infected.append(0)

infected
# Out:
# [0,
#  0,
#  0,
#  0,
#  0,
#  3,
#  0,
#  0,
#  0,
#  1,
#  1,
#  0,
#  1,
#  9,
#  71,
#  0,
#  1,
#  0,
#  8,
#  0,
#  0,
#  0,
#  1,
#  2,
#  10,
#  0,
#  1,
#  0,
#  3,
#  12,
#  0,
#  24,
#  6,
#  6,
#  17,
#  0,
#  13,
#  0,
#  2,
#  29,
#  1,
#  0,
#  1,
#  9,
#  1,
#  0,
#  6,
#  0,
#  5,
#  1,
#  0,
#  0,
#  0,
#  13,
#  0,
#  16,
#  0,
#  3,
#  0,
#  0,
#  0,
#  0,
#  12,
#  12]

# %%
districts_zillas["Infected"] = infected

# %%
fig, ax = plt.subplots(figsize=(20, 20))
ax = districts_zillas.plot(
    ax=ax, edgecolor="black", column="Infected", markersize=10, legend=True, cmap = "OrRd"
)

districts_zillas.apply(
    lambda x: ax.annotate(
        text=x.ADM2_EN, xy=x.geometry.centroid.coords[0], ha="center"
    ),
    axis=1,
)
ax.set_title("Heatmap of Infected by Zilla")
# Out:
# Text(0.5, 1.0, 'Heatmap of Infected by Zilla')
